# %%
# Libraries
import pandas as pd
import numpy  as np
import pickle as pkl

# %%
# Data Input
train_sessions = pd.read_csv('data/train_sessions.csv')
test_sessions = pd.read_csv('data/test_sessions.csv')
sample = pd.read_csv('data/sample_submission.csv')

with open('data/site_dic.pkl', 'rb') as f:
    site_dic = pkl.load(f)

# %%
# Dictionary does not include float values
sites = ['site%s' % i for i in range(1,11)]
times = ['time%s' % i for i in range(1,11)]
train_sessions[sites] = train_sessions[sites].fillna(0).apply(lambda col: col.astype(int), axis = 0)
test_sessions[sites]  = test_sessions[sites].fillna(0).apply(lambda col: col.astype(int), axis = 0)
train_sessions.head()
# Out:
#    session_id  site1                time1  site2                time2  site3  \
# 0           1    718  2014-02-20 10:02:45      0                  NaN      0
# 1           2    890  2014-02-22 11:19:50    941  2014-02-22 11:19:50   3847
# 2           3  14769  2013-12-16 16:40:17     39  2013-12-16 16:40:18  14768
# 3           4    782  2014-03-28 10:52:12    782  2014-03-28 10:52:42    782
# 4           5     22  2014-02-28 10:53:05    177  2014-02-28 10:55:22    175
#
#                  time3  site4                time4  site5   ...    \
# 0                  NaN      0                  NaN      0   ...
# 1  2014-02-22 11:19:51    941  2014-02-22 11:19:51    942   ...
# 2  2013-12-16 16:40:19  14769  2013-12-16 16:40:19     37   ...
# 3  2014-03-28 10:53:12    782  2014-03-28 10:53:42    782   ...
# 4  2014-02-28 10:55:22    178  2014-02-28 10:55:23    177   ...
#
#                  time6  site7                time7  site8  \
# ...

# %%
# Out:
# ['site1',
#  'site2',
#  'site3',
#  'site4',
#  'site5',
#  'site6',
#  'site7',
#  'site8',
#  'site9',
#  'site10']
